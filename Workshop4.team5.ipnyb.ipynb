# %%
#tmrin 2

import re

matn = input("enter your str")

re.findall(r'!?.,-' , matn)

# %%
#tmrin 3

import math
import statistics


majmoe = []

def varians(l1,teadad,miangin):
    """
    estefad az miangin va tedat baraye varians
    """
    j = 0

    while j < teadad:
         majmoe[j] = (majmoe[j] - miangin)**2
         j+=1

    varians =(sum(majmoe)/teadad) 
    return(varians)   
   
#daryafte teedad adadd  
tedad= int(input("che meghdar adad mikhahid vared konin ? "))
#daryaft khode adad
i = 0
while i < tedad:
    majmoe.append(int(input("adad ra vared konin = ")))
    i+=1
majmoe2 = majmoe.copy()    
miangin  = (sum(majmoe)/tedad)
print("miangin= ",miangin)
 
#varians
varians2 = varians(majmoe,tedad,miangin)  
print("varianse= ",varians2)

enheraf = math.sqrt(varians2)
print("enheraf meyar =",enheraf)
#max va min
print("max=", max(majmoe2))
print("min=", min(majmoe2))   

#mod
mod1 = statistics.mode(majmoe2)
print("mod =",mod1)

#cahrk
if (tedad - 1) % 2 != 0:
    addres = int((tedad-1)/2 + 0.5)
    addresQ = int((addres/2)+ -0.5)
    print("Q2 = ",majmoe2[addres])
    print(addresQ)
    
    
    
    
    
else:
    addres = int((tedad-1)/2)    
    addresQq = addres/2
    Q2 = (majmoe2[addres]+majmoe2[addres+1])/2
    print("Q2 =",Q2)

# %%
#tamrin 4

import os
 
dir_name = 'C:\Program Files\Java\jdk-11.0.13\include'
    
list_of_files = sorted( filter( lambda x: os.path.isfile(os.path.join(dir_name, x)) , os.listdir(dir_name) ) )
                 

for file_name in list_of_files:
    print(file_name)
     
###end of 4

# %%
#tamrin 5

nomarat = {'ali' : 18 , 'mahdi' : 20 , 'sina' : 16 , 'raza' : 12} 

sort_nomarat = sorted(nomarat.items() , key = lambda x : x[1] , reverse = True)

print("nozoli:")

for i in sort_nomarat :
    print(i[0] , i[1])
    
sort_nomarat_soudi = sorted(nomarat.items() , key = lambda x : x[1])

print("soudi:")

for i in sort_nomarat_soudi :
    print(i[0] , i[1])
